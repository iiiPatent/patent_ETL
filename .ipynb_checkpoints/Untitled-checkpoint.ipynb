# %%
import pymongo
from pymongo import MongoClient
client = MongoClient('mongodb://localhost:27017')  #連到本機端的mongodb
db = client['play_40']  #選擇database
collect = db['data40']  #選擇database.collection

count = 0
for dic in collect.find():  #選擇你要的欄位
    print dic['title']
    count += 1
print count
# Out:
# USB充電模組USB CHARGING MODULE
# 附有板體之流體壓力缸FLUID PRESSURE CYLINDER WITH PLATE
# 遙控器
# 遙控器
# 清潔刷CLEANING BRUSH
# 清潔刷CLEANING BRUSH
# 椅子零件
# 椅架(三)
# 椅架(四)
# 沙發
# 升降桌
# 置物盒
# 櫥櫃架銜接座
# 櫥櫃架銜接座(一)
# 封邊條
# 衣帽架掛桿
# 枕頭
# 枕頭
# 飲料容器
# 杯子
# 濾壺
# 烤肉機
# 溫奶器
# 脫水桶
# 拋棄式鑽頭
# 打釘機nailer
# 鐵皮剪手柄
# 蔬果園藝剪
# 螺絲起子A srewdriver
# 鉗子Pliers
# 鎖LOCK
# 瓶子
# 美容敷料容器(四)PACKING CONTAINER
# 美容敷料容器(五)PACKING CONTAINER
# 美容敷料容器(三)PACKING CONTAINER
# 美容敷料容器(七)PACKING CONTAINER
# 美容敷料容器(二)PACKING CONTAINER
# 美容敷料容器之蓋子CAP FOR PACKING CONTAINER
# 美容敷料容器(八)PACKING CONTAINER
# 美容敷料容器(九)PACKING CONTAINER
# 美容敷料容器(十)PACKING CONTAINER
# 瓶(罐)蓋
# 垃圾桶
# 兒童便器
# 碟形鐘
# 錶殼WATCH CASE
# 墜飾PENDANT
# 植栽容器(一)PLANT CONTAINER(I)
# 植栽容器(二)PLANT CONTAINER(Ⅱ)
# 植栽容器(三)PLANT CONTAINER (Ⅲ)
# 花器
# 電動車ELECTRIC VEHICLE
# 車架FRAME OF ELECTRIC VEHICLE
# 懷錶Pendant watch
# 火災煙霧偵測器
# 螢幕Monitor
# 座墊袋
# 自行車用前置型水壺
# 協力車
# 曲柄組
# 嬰兒車用托架Bracket for stroller
# 助立(行)器
# 車輛下護柵(一)VEHICLE LOWER GRILLE
# 車輛下護柵(二)VEHICLE LOWER GRILLE
# 車輛上護柵(一)VEHICLE UPPER GRILLE
# ...

# %%
dic = {'sjib':12,'sci':'drnv'}
print len(dic)
keys = dic.keys()
for i in keys:
    print i
collect.findOne()
# Out:
# 2
# sci
# sjib
