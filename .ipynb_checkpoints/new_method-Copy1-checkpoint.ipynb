# %%
#方法
import xmltodict
 
# It doesn't work with Python 3! Read on for the solution!
def convert(xml_file, xml_attribs=True):
    with open(xml_file) as f:
        d = xmltodict.parse(f, xml_attribs=xml_attribs)
        return d

# %%
#方法
from json import loads, dumps
from collections import OrderedDict

def to_dict(input_ordered_dict):
    return loads(dumps(input_ordered_dict))

# %%
#方法
def dickeys(dic):
    l = []
    for key in dic:
        if type(dic[key]) != type({}):
            if '@' not in key:
                l.append(key)
        else:
            for a in dickeys(dic[key]):
                l.append(key+'_'+a)
    return l

# %%
#try  recursive
#方法
def dickeys(dic):
    l = []
    for key in dic:
        if type(dic[key]) != type({}):
            if '@' not in key and 'p' not in key:
                l.append(key)
        else:
            for a in dickeys(dic[key]):
                l.append(key+'_'+a)
    return l

# %%
#叫三個方法
d = convert('E:/patent_data/catalog/cat40/40001/092134555.xml')
ddd= to_dict(d)
key_ary = dickeys(ddd)
#print ary
# Out:
# {u'tw-patent-grant': {u'claims': {u'claim': [{u'@num': u'1', u'@id': u'clm1', u'p': {u'#text': u'\u4e00\u7a2e\u53ef\u64f4\u5c55\u4e4b\u789f\u7247\u64ad\u653e\u5668\uff0c\u5305\u62ec\uff1a\u78ba\u5b9a\u88dd\u7f6e\uff0c\u7528\u4ee5\u78ba\u5b9a\u5728\u4e00\u789f\u7247\u4e0a\u4e4b\u4e00\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5167\u5bb9\u985e\u578b\uff0c\u5176\u4e2d\u82e5\u78ba\u5b9a\u7528\u65bc\u64ad\u653e\u8a72\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4fc2\u7f3a\u5c11\u6642\uff0c\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff1b\u6aa2\u67e5\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\u6642\uff0c\u7528\u4ee5\u6aa2\u67e5\u662f\u5426\u6709\u4e00\u4f4d\u5740\u4fc2\u53ef\u7528\u7684\uff0c\u5176\u4e2d\u8a72\u4f4d\u5740\u4ee3\u8868\u5305\u542b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7684\u4e00\u7db2\u7ad9\u7684\u4e00URL\uff1b\u4e0b\u8f09\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u4f4d\u5740\u4fc2\u53ef\u7528\u6642\uff0c\u7528\u65bc\u4e0b\u8f09\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u9810\u5132\u5b58\u88dd\u7f6e\uff0c\u7528\u4ee5\u9810\u5148\u5132\u5b58\u4e00\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\uff0c\u7d93\u9810\u9078\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u53ef\u5f9e\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e0b\u8f09\uff1b\u53ca\u6aa2\u67e5\u88dd\u7f6e\uff0c\u7528\u4ee5\u6aa2\u67e5\u8207\u8a72\u78ba\u5b9a\u4e4b\u5167\u5bb9\u985e\u578b\u76f8\u95dc\u806f\u4e4b\u4e00\u4f4d\u5740\u662f\u5426\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u3002', u'@type': u'claim-text'}}, {u'@num': u'2', u'@id': u'clm2', u'p': {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u5b58\u53d6\u88dd\u7f6e\uff0c\u7576\u6aa2\u67e5\u8207\u8a72\u5167\u5bb9\u985e\u578b\u76f8\u95dc\u806f\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u7528\u4ee5\u5b58\u53d6\u4e00\u9810\u8a2d\u7db2\u7ad9\u4ee5\u641c\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}}, {u'@num': u'3', u'@id': u'clm3', u'p': {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c2\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u5176\u4e2d\u8a72\u5b58\u53d6\u88dd\u7f6e\u5305\u62ec\u767c\u9001\u88dd\u7f6e\uff0c\u7528\u4ee5\u5411\u8a72\u9810\u8a2d\u7db2\u7ad9\u767c\u9001\u9644\u6709\u95dc\u65bc\u8a72\u64ad\u653e\u5668\u53ca\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u76f8\u95dc\u8cc7\u8a0a\u7684\u8acb\u6c42\u3002', u'@type': u'claim-text'}}, {u'@num': u'4', u'@id': u'clm4', u'p': {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u78ba\u5b9a\u88dd\u7f6e\uff0c\u7528\u4ee5\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u53ef\u7372\u5f97\uff0c\u53ca\u4e0b\u8f09\u88dd\u7f6e\uff0c\u7576\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u53ef\u7372\u5f97\u6642\uff0c\u7528\u4ee5\u4e0b\u8f09\u8a72\u89e3\u78bc\n\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}}, {u'@num': u'5', u'@id': u'clm5', u'p': {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c4\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u901a\u77e5\u88dd\u7f6e\uff0c\u7576\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7121\u6cd5\u7372\u5f97\u6642\uff0c\u7528\u4ee5\u901a\u77e5\u4e00\u4f7f\u7528\u8005\u3002', u'@type': u'claim-text'}}, {u'@num': u'6', u'@id': u'clm6', u'p': {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u81f4\u80fd\u88dd\u7f6e\uff0c\u4f7f\u4e00\u4f7f\u7528\u8005\u80fd\u5920\u4eba\u5de5\u5730\u522a\u9664\u4e00\u4e0b\u8f09\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}}, {u'@num': u'7', u'@id': u'clm7', u'p': {u'#text': u'\u4e00\u7a2e\u53ef\u64f4\u5c55\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u5176\u5305\u542b\uff1a\u78ba\u5b9 ...

# %%
from bs4 import BeautifulSoup as bs
fi = open('E:/patent_data/catalog/cat40/40001/092134555.xml','r')
xml = bs(fi.read())
fi.close()
for keys in key_ary:
    w = ' > '.join(keys.split('_'))
    if len(xml.select(w)) != 0:
        print w, xml.select(w)[0].text
# Out:
# tw-patent-grant > claims > claim
# 一種可擴展之碟片播放器，包括：確定裝置，用以確定在一碟片上之一內容物件之一內容類型，其中若確定用於播放該內容物件之一合適的解碼程式係缺少時，確定該內容類型係未知；檢查裝置，在確定該內容類型係未知時，用以檢查是否有一位址係可用的，其中該位址代表包含一合適的解碼程式的一網站的一URL；下載裝置，在確定該位址係可用時，用於下載該合適的解碼程式；預儲存裝置，用以預先儲存一預設位址目錄，經預選之解碼程式可從該預設位址目錄下載；及檢查裝置，用以檢查與該確定之內容類型相關聯之一位址是否存在於該預設位址目錄中。
#
#
# tw-patent-grant > drawings > figure
#
#
# tw-patent-grant > tw-bibliographic-data-grant > publication-reference > document-id > date 102/01/01
# tw-patent-grant > tw-bibliographic-data-grant > publication-reference > document-id > kind
# tw-patent-grant > tw-bibliographic-data-grant > publication-reference > document-id > doc-number I381317
# tw-patent-grant > tw-bibliographic-data-grant > volno 40
# tw-patent-grant > tw-bibliographic-data-grant > refs > ref
# TW
# 432360
#
#
# tw-patent-grant > tw-bibliographic-data-grant > examiners > examiner > chinese-name > first-name
# tw-patent-grant > tw-bibliographic-data-grant > examiners > examiner > chinese-name > last-name 潘世光
# tw-patent-grant > tw-bibliographic-data-grant > parties > inventors > inventor
#
#
# 彭楊
#
#
#
# PENG, YANG
#
#
#
#
# CN
# CN
#
#
# tw-patent-grant > tw-bibliographic-data-grant > parties > agents > agent > addressbook > address 臺北市
# tw-patent-grant > tw-bibliographic-data-grant > parties > agents > agent > addressbook > chinese-name > first-name
# tw-patent-grant > tw-bibliographic-data-grant > parties > agents > agent > addressbook > chinese-name > last-name 陳長文
# tw-patent-grant > tw-bibliographic-data-grant > parties > applicants > applicant > addressbook > english-name > first-name
# tw-patent-grant > tw-bibliographic-data-grant > parties > applicants > applicant > addressbook > english-name > middle-name
# tw-patent-grant > tw-bibliographic-data-grant > parties > applicants > applicant > addressbook > english-name > last-name KONINKLIJKE PHILIPS ELECTRONICS N.V.
# tw-patent-grant > tw-bibliographic-data-grant > parties > applicants > applicant > addressbook > english-address NL
# tw-patent-grant > tw-bibliographic-data-grant > parties > applicants > applicant > addressbook > english-country NL
# tw-patent-grant > tw-bibliographic-data-grant > parties > applicants > applicant > addressbook > address
# tw-patent-grant > tw-bibliographic-data-grant > parties > applicants > applicant > addressbook > chinese-name > first-name
# tw-patent-grant > tw-bibliographic-data-grant > parties > applicants > applicant > addressbook > chinese-name > last-name 皇家飛利浦電子股份有限公司
# tw-patent-grant > tw-bibliographic-data-grant > isuno 1
# tw-patent-grant > tw-bibliographic-data-grant > application-publication-reference > document-id > date 94/06/16
# tw-patent-grant > tw-bibliographic-data-grant > application-publication-reference > document-id > kind
# tw-patent-grant > tw-bibliographic-data-grant > application-publication-reference > document-id > doc-number 200519760
# tw-patent-grant > tw-bibliographic-data-grant > application-reference > document-id > date 92/12/08
# tw-patent-grant > tw-bibliographic-data-grant > application-reference > document-id > kind
# tw-patent-grant > tw-bibliographic-data-grant > application-reference > document-id > doc-number 092134555
# tw-patent-grant > tw-bibliographic-data-grant > invention-title > english-title EXTENSIBLE DISC PLAYER
# tw-patent-grant > tw-bibliographic-data-grant > invention-title > chinese-title 可擴展之光碟播放機
# tw-patent-grant > tw-bibliographic-data-grant > certificate-number > document-id > date
# tw-patent-grant > tw-bibliographic-data-grant > certificate-number > document-id > kind
# tw-patent-grant > tw-bibliographic-data-grant > certificate-number > document-id > doc-number I381317
# tw-patent-grant > tw-bibliographic-data-grant > kindcode B1

# %%
#叫三個方法
def fileconvert(file_name):
    d = convert(file_name) #原始檔轉成dic
    ddd= to_dict(d)        #再轉成dic
    ary = dickeys(ddd)     #抓出所有key
    return ary

# %%
dic = {'sr':'123'}
dic['sr'] += '456'
print dic
# Out:
# {'sr': '123456'}

# %%
# Out:
# [u'tw-patent-grant_claims_claim', u'tw-patent-grant_drawings_figure', u'tw-patent-grant_tw-bibliographic-data-grant_publication-reference_document-id_date', u'tw-patent-grant_tw-bibliographic-data-grant_publication-reference_document-id_kind', u'tw-patent-grant_tw-bibliographic-data-grant_publication-reference_document-id_doc-number', u'tw-patent-grant_tw-bibliographic-data-grant_volno', u'tw-patent-grant_tw-bibliographic-data-grant_refs_ref', u'tw-patent-grant_tw-bibliographic-data-grant_classification-ipc_main-classification_#text', u'tw-patent-grant_tw-bibliographic-data-grant_examiners_examiner_chinese-name_first-name', u'tw-patent-grant_tw-bibliographic-data-grant_examiners_examiner_chinese-name_last-name', u'tw-patent-grant_tw-bibliographic-data-grant_parties_inventors_inventor', u'tw-patent-grant_tw-bibliographic-data-grant_parties_agents_agent_addressbook_address', u'tw-patent-grant_tw-bibliographic-data-grant_parties_agents_agent_addressbook_chinese-name_first-name', u'tw-patent-grant_tw-bibliographic-data-grant_parties_agents_agent_addressbook_chinese-name_last-name', u'tw-patent-grant_tw-bibliographic-data-grant_parties_applicants_applicant_addressbook_english-name_first-name', u'tw-patent-grant_tw-bibliographic-data-grant_parties_applicants_applicant_addressbook_english-name_middle-name', u'tw-patent-grant_tw-bibliographic-data-grant_parties_applicants_applicant_addressbook_english-name_last-name', u'tw-patent-grant_tw-bibliographic-data-grant_parties_applicants_applicant_addressbook_english-address', u'tw-patent-grant_tw-bibliographic-data-grant_parties_applicants_applicant_addressbook_english-country', u'tw-patent-grant_tw-bibliographic-data-grant_parties_applicants_applicant_addressbook_address', u'tw-patent-grant_tw-bibliographic-data-grant_parties_applicants_applicant_addressbook_chinese-name_first-name', u'tw-patent-grant_tw-bibliographic-data-grant_parties_applicants_applicant_addressbook_chinese-name_last-name', u'tw-patent-grant_tw-bibliographic-data-grant_isuno', u'tw-patent-grant_tw-bibliographic-data-grant_application-publication-reference_document-id_date', u'tw-patent-grant_tw-bibliographic-data-grant_application-publication-reference_document-id_kind', u'tw-patent-grant_tw-bibliographic-data-grant_application-publication-reference_document-id_doc-number', u'tw-patent-grant_tw-bibliographic-data-grant_application-reference_document-id_date', u'tw-patent-grant_tw-bibliographic-data-grant_application-reference_document-id_kind', u'tw-patent-grant_tw-bibliographic-data-grant_application-reference_document-id_doc-number', u'tw-patent-grant_tw-bibliographic-data-grant_invention-title_english-title', u'tw-patent-grant_tw-bibliographic-data-grant_invention-title_chinese-title', u'tw-patent-grant_tw-bibliographic-data-grant_certificate-number_document-id_date', u'tw-patent-grant_tw-bibliographic-data-grant_certificate-number_document-id_kind', u'tw-patent-grant_tw-bibliographic-data-grant_certificate-number_document-id_doc-number', u'tw-patent-grant_tw-bibliographic-data-grant_kindcode']

# %%
from bs4 import BeautifulSoup as bs
def build_dic(file_name):
    fi = open(file_name,'r')
    xml = bs(fi.read())
    fi.close()    

    #dic = {}
    key_ary = fileconvert(file_name)
    for keys in key_ary:
        w = ' > '.join(keys.split('_'))
        if len(xml.select(w)) != 0:
            dic_key = keys.encode('utf-8')
            #dic.update({dic_key:''})
            for i in xml.select(w):
                dic[dic_key] += i.text.strip().encode('utf-8')
    return dic

# %%
print build_dic('E:\\patent_data\\catalog\\cat41\\41004\\093138921.xml')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-1ff1e6d8f2e3> in <module>()
# ----> 1 print build_dic('E:\\patent_data\\catalog\\cat41\\41004\\093138921.xml')
#
# <ipython-input-93-bd9860024158> in build_dic(file_name)
#      13             #dic.update({dic_key:''})
#      14             for i in xml.select(w):
# ---> 15                 dic[dic_key] += i.text.strip().encode('utf-8')
#      16     return dic
#
# KeyError: 'tw-patent-grant_tw-bibliographic-data-grant_priority-claims_priority-claim_date'

# %%
for key in dic:
    print key, dic[key]
# Out:
# tw-patent-grant_tw-bibliographic-data-grant_parties_applicants_applicant_addressbook_english-name_first-name
# tw-patent-grant_tw-bibliographic-data-grant_certificate-number_document-id_date
# tw-patent-grant_tw-bibliographic-data-grant_parties_applicants_applicant_addressbook_chinese-name_first-name
# tw-patent-grant_tw-bibliographic-data-grant_certificate-number_document-id_doc-number I381317
# tw-patent-grant_tw-bibliographic-data-grant_parties_applicants_applicant_addressbook_english-name_middle-name
# tw-patent-grant_tw-bibliographic-data-grant_invention-title_english-title EXTENSIBLE DISC PLAYER
# tw-patent-grant_tw-bibliographic-data-grant_application-reference_document-id_doc-number 092134555
# tw-patent-grant_tw-bibliographic-data-grant_examiners_examiner_chinese-name_first-name
# tw-patent-grant_tw-bibliographic-data-grant_parties_applicants_applicant_addressbook_english-name_last-name KONINKLIJKE PHILIPS ELECTRONICS N.V.
# tw-patent-grant_tw-bibliographic-data-grant_publication-reference_document-id_doc-number I381317
# tw-patent-grant_tw-bibliographic-data-grant_application-reference_document-id_date 92/12/08
# tw-patent-grant_tw-bibliographic-data-grant_certificate-number_document-id_kind
# tw-patent-grant_tw-bibliographic-data-grant_parties_agents_agent_addressbook_chinese-name_last-name 陳長文
# tw-patent-grant_tw-bibliographic-data-grant_application-publication-reference_document-id_kind
# tw-patent-grant_tw-bibliographic-data-grant_publication-reference_document-id_kind
# tw-patent-grant_tw-bibliographic-data-grant_invention-title_chinese-title 可擴展之光碟播放機
# tw-patent-grant_tw-bibliographic-data-grant_kindcode B1
# tw-patent-grant_tw-bibliographic-data-grant_examiners_examiner_chinese-name_last-name 潘世光
# tw-patent-grant_tw-bibliographic-data-grant_parties_applicants_applicant_addressbook_english-country NL
# tw-patent-grant_tw-bibliographic-data-grant_parties_applicants_applicant_addressbook_chinese-name_last-name 皇家飛利浦電子股份有限公司
# tw-patent-grant_tw-bibliographic-data-grant_parties_applicants_applicant_addressbook_address
# tw-patent-grant_tw-bibliographic-data-grant_application-reference_document-id_kind
# tw-patent-grant_tw-bibliographic-data-grant_parties_agents_agent_addressbook_address 臺北市
# tw-patent-grant_tw-bibliographic-data-grant_isuno 1
# tw-patent-grant_tw-bibliographic-data-grant_parties_inventors_inventor 彭楊
#
#
#
# PENG, YANG
#
#
#
#
# CN
# CN迪卡蘭   凱利
#
#
#
# KELLY, DECLAN
#
#
#
#
# IE
# IE王蓓
#
#
#
# WANG, BEI
#
#
#
#
# CN
# CN何達華
#
#
#
# HE, DAHUA
#
#
#
#
# CN
# CN
# tw-patent-grant_tw-bibliographic-data-grant_publication-reference_document-id_date 102/01/01
# tw-patent-grant_tw-bibliographic-data-grant_application-publication-reference_document-id_date 94/06/16
# tw-patent-grant_drawings_figure
# tw-patent-grant_tw-bibliographic-data-grant_refs_ref TW
# 432360GB
# 2332772
# AUS
# 6216152
# B1WO
# 00/63915
# A1
# tw-patent-grant_tw-bibliographic-data-grant_application-publication-reference_document-id_doc-number 200519760
# tw-patent-grant_tw-bibliographic-data-grant_parties_applicants_applicant_addressbook_english-address NL
# tw-patent-grant_claims_claim 一種可擴展之碟片播放器，包括：確定裝置，用以確定在一碟片上之一內容物件之一內容類型，其中若確定用於播放該內容物件之一合適的解碼程式係缺少時，確定該內容類型係未知；檢查裝置，在確定該內容類型係未知時，用以檢查是否有一位址係可用的，其中該位址代表包含一合適的解碼程式的一網站的一URL；下載裝置，在確定該位址係可用時，用於下載該合適的解碼程式；預儲存裝置，用以預先儲存一預設位址目錄，經預選之解碼程式可從該預設位址目錄下載；及檢查裝置，用以檢查與該確定之內容類型相關聯之一位址是否存在於該預設位址目錄中。如申請專利範圍第1項之播放器，進一步包含存取裝置，當檢查與該內容類型相關聯之該位址不存在於該預設位址目錄中時，用以存取一預設網站以搜索一合適的解碼程式。如申請專利範圍第2項之播放器，其中該存取裝置包括發送裝置，用以向該預設網站發送附有關於該播放器及該內容類型之相關資訊的請求。如申請專利範圍第1項之播放器，進一步包含確定裝置，用以確定該合適的解碼程式可獲得，及下載裝置，當確定該合適的解碼程式可獲得時，用以下載該解碼
# 程式。如申請專利範圍第4項之播放器，進一步包含通知裝置，當確定該合適的解碼程式無法獲得時，用以通知一使用者。如申請專利範圍第1項之播放器，進一步包含致能裝置，使一使用者能夠人工地刪除一下載的解碼程式。一種可擴展之播放設備，其包含：確定裝置，用以確定在一資料儲存元件上之一內容物件之一內容類型，其中若該可擴展之播放設備缺少一合適的解碼程式以撥放該內容物件時，則確定該內容類型係未知；確定裝置，在確定該內容類型係未知時，用以確定該資料儲存元件是否包含一連結至包含一合適的解碼程式的一網站之URL位址；下載裝置，在確定該資料儲存元件包含該位址時，用於下載該合適的解碼程式；預儲存裝置，用以預先儲存一預設位址目錄，該預設位址目錄包含至網站之連結，經預選之解碼程式可從該等網站下載；及檢查裝置，用以檢查該內容類型之一位址是否存在於該預設位址目錄中。如申請專利範圍第7項之播放設備，進一步包含存取裝置，當檢查該內容類型之該位址不存在於該預設位址目錄中時，用以存取該播放設備之製造者的網站，
# 以使該製造者的網站搜索一合適的解碼程式。如申請專利範圍第8項之播放設備，其中該存取裝置包括發送裝置，用以向該製造者的網站發送附有關於該播放設備及該內容類型之相關資訊的請求。一種用以升級碟片播放器之方法，其包括：確定一碟片上之一內容物件之一內容類型，其中若該播放器缺少一合適的解碼程式以播放該內容物件時，則確定該內容類型係未知；若該內容類型係未知，則確定該碟片是否包含一連結至包含一合適的解碼程式的一網站之URL位址；若該碟片包含該位址，則使用該位址下載該合適的解碼程式；預先儲存一預設位址目錄，該預設位址目錄包含至網站之連結，經預選之解碼程式可從該等網站下載；及若該碟片未包含該位址，則檢查該內容類型之一位址是否存在於該預設位址目錄中。如申請專利範圍第10項之方法，進一步包含若該內容類型之該位址不存在於該預設位址目錄中時，則存取該播放器之製造者網站，以使該網站檢索一合適的解碼程式之步驟。如申請專利範圍第11項之方法，其中該存取步驟包括向該製造者網站發送附與該播放器及該內容類型有關的資訊之請求的步驟。如申請專利範圍第10項之方法，進一步包括：
# 確定是否能自該網站獲得該合適的解碼程式；若能獲得該合適的解碼程式，則下載該解碼程式。如申請專利範圍第13項之方法，進一步包括若不能自該網站獲得該合適的解碼程式，則通知一使用者之步驟。如申請專利範圍第10項之方法，進一步包括使一使用者能人工地自該播放器刪除一下載之解碼程式的步驟。
# tw-patent-grant_tw-bibliographic-data-grant_volno 40
# tw-patent-grant_tw-bibliographic-data-grant_parties_agents_agent_addressbook_chinese-name_first-name

# %%
line.strip() for line in fp if len(line) > 10  (?)

# %%
print type(ddd)
# Out:
# <type 'dict'>

# %%
for i in ary:
    s = ''
    for w in i.split('_'):
        #print type(ddd)
        #print ddd[w]
        if type(ddd)==type({}):
            #print 'if'
            ddd = ddd[w]
            print type(ddd)
        else:
            for q in ddd:
                for key in q:
                    print key,q[key]
                #print type(q)
    #print type(ddd)
    print '='*100
    
        #s += '["%s"]'%(w)
    #print ddd + s
    #print ddd["tw-patent-grant"]["tw-bibliographic-data-grant"]["volno"]
# Out:
# <type 'dict'>
# <type 'dict'>
# <type 'list'>
# ====================================================================================================
# @num 1
# @id clm1
# p {u'#text': u'\u4e00\u7a2e\u53ef\u64f4\u5c55\u4e4b\u789f\u7247\u64ad\u653e\u5668\uff0c\u5305\u62ec\uff1a\u78ba\u5b9a\u88dd\u7f6e\uff0c\u7528\u4ee5\u78ba\u5b9a\u5728\u4e00\u789f\u7247\u4e0a\u4e4b\u4e00\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5167\u5bb9\u985e\u578b\uff0c\u5176\u4e2d\u82e5\u78ba\u5b9a\u7528\u65bc\u64ad\u653e\u8a72\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4fc2\u7f3a\u5c11\u6642\uff0c\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff1b\u6aa2\u67e5\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\u6642\uff0c\u7528\u4ee5\u6aa2\u67e5\u662f\u5426\u6709\u4e00\u4f4d\u5740\u4fc2\u53ef\u7528\u7684\uff0c\u5176\u4e2d\u8a72\u4f4d\u5740\u4ee3\u8868\u5305\u542b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7684\u4e00\u7db2\u7ad9\u7684\u4e00URL\uff1b\u4e0b\u8f09\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u4f4d\u5740\u4fc2\u53ef\u7528\u6642\uff0c\u7528\u65bc\u4e0b\u8f09\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u9810\u5132\u5b58\u88dd\u7f6e\uff0c\u7528\u4ee5\u9810\u5148\u5132\u5b58\u4e00\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\uff0c\u7d93\u9810\u9078\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u53ef\u5f9e\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e0b\u8f09\uff1b\u53ca\u6aa2\u67e5\u88dd\u7f6e\uff0c\u7528\u4ee5\u6aa2\u67e5\u8207\u8a72\u78ba\u5b9a\u4e4b\u5167\u5bb9\u985e\u578b\u76f8\u95dc\u806f\u4e4b\u4e00\u4f4d\u5740\u662f\u5426\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u3002', u'@type': u'claim-text'}
# @num 2
# @id clm2
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u5b58\u53d6\u88dd\u7f6e\uff0c\u7576\u6aa2\u67e5\u8207\u8a72\u5167\u5bb9\u985e\u578b\u76f8\u95dc\u806f\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u7528\u4ee5\u5b58\u53d6\u4e00\u9810\u8a2d\u7db2\u7ad9\u4ee5\u641c\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 3
# @id clm3
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c2\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u5176\u4e2d\u8a72\u5b58\u53d6\u88dd\u7f6e\u5305\u62ec\u767c\u9001\u88dd\u7f6e\uff0c\u7528\u4ee5\u5411\u8a72\u9810\u8a2d\u7db2\u7ad9\u767c\u9001\u9644\u6709\u95dc\u65bc\u8a72\u64ad\u653e\u5668\u53ca\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u76f8\u95dc\u8cc7\u8a0a\u7684\u8acb\u6c42\u3002', u'@type': u'claim-text'}
# @num 4
# @id clm4
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u78ba\u5b9a\u88dd\u7f6e\uff0c\u7528\u4ee5\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u53ef\u7372\u5f97\uff0c\u53ca\u4e0b\u8f09\u88dd\u7f6e\uff0c\u7576\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u53ef\u7372\u5f97\u6642\uff0c\u7528\u4ee5\u4e0b\u8f09\u8a72\u89e3\u78bc\n\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 5
# @id clm5
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c4\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u901a\u77e5\u88dd\u7f6e\uff0c\u7576\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7121\u6cd5\u7372\u5f97\u6642\uff0c\u7528\u4ee5\u901a\u77e5\u4e00\u4f7f\u7528\u8005\u3002', u'@type': u'claim-text'}
# @num 6
# @id clm6
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u81f4\u80fd\u88dd\u7f6e\uff0c\u4f7f\u4e00\u4f7f\u7528\u8005\u80fd\u5920\u4eba\u5de5\u5730\u522a\u9664\u4e00\u4e0b\u8f09\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 7
# @id clm7
# p {u'#text': u'\u4e00\u7a2e\u53ef\u64f4\u5c55\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u5176\u5305\u542b\uff1a\u78ba\u5b9a\u88dd\u7f6e\uff0c\u7528\u4ee5\u78ba\u5b9a\u5728\u4e00\u8cc7\u6599\u5132\u5b58\u5143\u4ef6\u4e0a\u4e4b\u4e00\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5167\u5bb9\u985e\u578b\uff0c\u5176\u4e2d\u82e5\u8a72\u53ef\u64f4\u5c55\u4e4b\u64ad\u653e\u8a2d\u5099\u7f3a\u5c11\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4ee5\u64a5\u653e\u8a72\u5167\u5bb9\u7269\u4ef6\u6642\uff0c\u5247\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff1b\u78ba\u5b9a\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\u6642\uff0c\u7528\u4ee5\u78ba\u5b9a\u8a72\u8cc7\u6599\u5132\u5b58\u5143\u4ef6\u662f\u5426\u5305\u542b\u4e00\u9023\u7d50\u81f3\u5305\u542b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7684\u4e00\u7db2\u7ad9\u4e4bURL\u4f4d\u5740\uff1b\u4e0b\u8f09\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u8cc7\u6599\u5132\u5b58\u5143\u4ef6\u5305\u542b\u8a72\u4f4d\u5740\u6642\uff0c\u7528\u65bc\u4e0b\u8f09\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u9810\u5132\u5b58\u88dd\u7f6e\uff0c\u7528\u4ee5\u9810\u5148\u5132\u5b58\u4e00\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\uff0c\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u5305\u542b\u81f3\u7db2\u7ad9\u4e4b\u9023\u7d50\uff0c\u7d93\u9810\u9078\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u53ef\u5f9e\u8a72\u7b49\u7db2\u7ad9\u4e0b\u8f09\uff1b\u53ca\u6aa2\u67e5\u88dd\u7f6e\uff0c\u7528\u4ee5\u6aa2\u67e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u4e00\u4f4d\u5740\u662f\u5426\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u3002', u'@type': u'claim-text'}
# @num 8
# @id clm8
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c7\u9805\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u9032\u4e00\u6b65\u5305\u542b\u5b58\u53d6\u88dd\u7f6e\uff0c\u7576\u6aa2\u67e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u7528\u4ee5\u5b58\u53d6\u8a72\u64ad\u653e\u8a2d\u5099\u4e4b\u88fd\u9020\u8005\u7684\u7db2\u7ad9\uff0c\n\u4ee5\u4f7f\u8a72\u88fd\u9020\u8005\u7684\u7db2\u7ad9\u641c\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 9
# @id clm9
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c8\u9805\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u5176\u4e2d\u8a72\u5b58\u53d6\u88dd\u7f6e\u5305\u62ec\u767c\u9001\u88dd\u7f6e\uff0c\u7528\u4ee5\u5411\u8a72\u88fd\u9020\u8005\u7684\u7db2\u7ad9\u767c\u9001\u9644\u6709\u95dc\u65bc\u8a72\u64ad\u653e\u8a2d\u5099\u53ca\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u76f8\u95dc\u8cc7\u8a0a\u7684\u8acb\u6c42\u3002', u'@type': u'claim-text'}
# @num 10
# @id clm10
# p {u'#text': u'\u4e00\u7a2e\u7528\u4ee5\u5347\u7d1a\u789f\u7247\u64ad\u653e\u5668\u4e4b\u65b9\u6cd5\uff0c\u5176\u5305\u62ec\uff1a\u78ba\u5b9a\u4e00\u789f\u7247\u4e0a\u4e4b\u4e00\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5167\u5bb9\u985e\u578b\uff0c\u5176\u4e2d\u82e5\u8a72\u64ad\u653e\u5668\u7f3a\u5c11\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4ee5\u64ad\u653e\u8a72\u5167\u5bb9\u7269\u4ef6\u6642\uff0c\u5247\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff1b\u82e5\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff0c\u5247\u78ba\u5b9a\u8a72\u789f\u7247\u662f\u5426\u5305\u542b\u4e00\u9023\u7d50\u81f3\u5305\u542b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7684\u4e00\u7db2\u7ad9\u4e4bURL\u4f4d\u5740\uff1b\u82e5\u8a72\u789f\u7247\u5305\u542b\u8a72\u4f4d\u5740\uff0c\u5247\u4f7f\u7528\u8a72\u4f4d\u5740\u4e0b\u8f09\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u9810\u5148\u5132\u5b58\u4e00\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\uff0c\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u5305\u542b\u81f3\u7db2\u7ad9\u4e4b\u9023\u7d50\uff0c\u7d93\u9810\u9078\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u53ef\u5f9e\u8a72\u7b49\u7db2\u7ad9\u4e0b\u8f09\uff1b\u53ca\u82e5\u8a72\u789f\u7247\u672a\u5305\u542b\u8a72\u4f4d\u5740\uff0c\u5247\u6aa2\u67e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u4e00\u4f4d\u5740\u662f\u5426\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u3002', u'@type': u'claim-text'}
# @num 11
# @id clm11
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c10\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u542b\u82e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u5247\u5b58\u53d6\u8a72\u64ad\u653e\u5668\u4e4b\u88fd\u9020\u8005\u7db2\u7ad9\uff0c\u4ee5\u4f7f\u8a72\u7db2\u7ad9\u6aa2\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4e4b\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 12
# @id clm12
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c11\u9805\u4e4b\u65b9\u6cd5\uff0c\u5176\u4e2d\u8a72\u5b58\u53d6\u6b65\u9a5f\u5305\u62ec\u5411\u8a72\u88fd\u9020\u8005\u7db2\u7ad9\u767c\u9001\u9644\u8207\u8a72\u64ad\u653e\u5668\u53ca\u8a72\u5167\u5bb9\u985e\u578b\u6709\u95dc\u7684\u8cc7\u8a0a\u4e4b\u8acb\u6c42\u7684\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 13
# @id clm13
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c10\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u62ec\uff1a\n\u78ba\u5b9a\u662f\u5426\u80fd\u81ea\u8a72\u7db2\u7ad9\u7372\u5f97\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u82e5\u80fd\u7372\u5f97\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff0c\u5247\u4e0b\u8f09\u8a72\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 14
# @id clm14
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c13\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u62ec\u82e5\u4e0d\u80fd\u81ea\u8a72\u7db2\u7ad9\u7372\u5f97\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff0c\u5247\u901a\u77e5\u4e00\u4f7f\u7528\u8005\u4e4b\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 15
# @id clm15
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c10\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u62ec\u4f7f\u4e00\u4f7f\u7528\u8005\u80fd\u4eba\u5de5\u5730\u81ea\u8a72\u64ad\u653e\u5668\u522a\u9664\u4e00\u4e0b\u8f09\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u7684\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 1
# @id clm1
# p {u'#text': u'\u4e00\u7a2e\u53ef\u64f4\u5c55\u4e4b\u789f\u7247\u64ad\u653e\u5668\uff0c\u5305\u62ec\uff1a\u78ba\u5b9a\u88dd\u7f6e\uff0c\u7528\u4ee5\u78ba\u5b9a\u5728\u4e00\u789f\u7247\u4e0a\u4e4b\u4e00\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5167\u5bb9\u985e\u578b\uff0c\u5176\u4e2d\u82e5\u78ba\u5b9a\u7528\u65bc\u64ad\u653e\u8a72\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4fc2\u7f3a\u5c11\u6642\uff0c\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff1b\u6aa2\u67e5\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\u6642\uff0c\u7528\u4ee5\u6aa2\u67e5\u662f\u5426\u6709\u4e00\u4f4d\u5740\u4fc2\u53ef\u7528\u7684\uff0c\u5176\u4e2d\u8a72\u4f4d\u5740\u4ee3\u8868\u5305\u542b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7684\u4e00\u7db2\u7ad9\u7684\u4e00URL\uff1b\u4e0b\u8f09\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u4f4d\u5740\u4fc2\u53ef\u7528\u6642\uff0c\u7528\u65bc\u4e0b\u8f09\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u9810\u5132\u5b58\u88dd\u7f6e\uff0c\u7528\u4ee5\u9810\u5148\u5132\u5b58\u4e00\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\uff0c\u7d93\u9810\u9078\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u53ef\u5f9e\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e0b\u8f09\uff1b\u53ca\u6aa2\u67e5\u88dd\u7f6e\uff0c\u7528\u4ee5\u6aa2\u67e5\u8207\u8a72\u78ba\u5b9a\u4e4b\u5167\u5bb9\u985e\u578b\u76f8\u95dc\u806f\u4e4b\u4e00\u4f4d\u5740\u662f\u5426\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u3002', u'@type': u'claim-text'}
# @num 2
# @id clm2
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u5b58\u53d6\u88dd\u7f6e\uff0c\u7576\u6aa2\u67e5\u8207\u8a72\u5167\u5bb9\u985e\u578b\u76f8\u95dc\u806f\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u7528\u4ee5\u5b58\u53d6\u4e00\u9810\u8a2d\u7db2\u7ad9\u4ee5\u641c\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 3
# @id clm3
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c2\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u5176\u4e2d\u8a72\u5b58\u53d6\u88dd\u7f6e\u5305\u62ec\u767c\u9001\u88dd\u7f6e\uff0c\u7528\u4ee5\u5411\u8a72\u9810\u8a2d\u7db2\u7ad9\u767c\u9001\u9644\u6709\u95dc\u65bc\u8a72\u64ad\u653e\u5668\u53ca\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u76f8\u95dc\u8cc7\u8a0a\u7684\u8acb\u6c42\u3002', u'@type': u'claim-text'}
# @num 4
# @id clm4
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u78ba\u5b9a\u88dd\u7f6e\uff0c\u7528\u4ee5\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u53ef\u7372\u5f97\uff0c\u53ca\u4e0b\u8f09\u88dd\u7f6e\uff0c\u7576\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u53ef\u7372\u5f97\u6642\uff0c\u7528\u4ee5\u4e0b\u8f09\u8a72\u89e3\u78bc\n\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 5
# @id clm5
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c4\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u901a\u77e5\u88dd\u7f6e\uff0c\u7576\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7121\u6cd5\u7372\u5f97\u6642\uff0c\u7528\u4ee5\u901a\u77e5\u4e00\u4f7f\u7528\u8005\u3002', u'@type': u'claim-text'}
# @num 6
# @id clm6
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u81f4\u80fd\u88dd\u7f6e\uff0c\u4f7f\u4e00\u4f7f\u7528\u8005\u80fd\u5920\u4eba\u5de5\u5730\u522a\u9664\u4e00\u4e0b\u8f09\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 7
# @id clm7
# p {u'#text': u'\u4e00\u7a2e\u53ef\u64f4\u5c55\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u5176\u5305\u542b\uff1a\u78ba\u5b9a\u88dd\u7f6e\uff0c\u7528\u4ee5\u78ba\u5b9a\u5728\u4e00\u8cc7\u6599\u5132\u5b58\u5143\u4ef6\u4e0a\u4e4b\u4e00\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5167\u5bb9\u985e\u578b\uff0c\u5176\u4e2d\u82e5\u8a72\u53ef\u64f4\u5c55\u4e4b\u64ad\u653e\u8a2d\u5099\u7f3a\u5c11\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4ee5\u64a5\u653e\u8a72\u5167\u5bb9\u7269\u4ef6\u6642\uff0c\u5247\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff1b\u78ba\u5b9a\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\u6642\uff0c\u7528\u4ee5\u78ba\u5b9a\u8a72\u8cc7\u6599\u5132\u5b58\u5143\u4ef6\u662f\u5426\u5305\u542b\u4e00\u9023\u7d50\u81f3\u5305\u542b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7684\u4e00\u7db2\u7ad9\u4e4bURL\u4f4d\u5740\uff1b\u4e0b\u8f09\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u8cc7\u6599\u5132\u5b58\u5143\u4ef6\u5305\u542b\u8a72\u4f4d\u5740\u6642\uff0c\u7528\u65bc\u4e0b\u8f09\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u9810\u5132\u5b58\u88dd\u7f6e\uff0c\u7528\u4ee5\u9810\u5148\u5132\u5b58\u4e00\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\uff0c\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u5305\u542b\u81f3\u7db2\u7ad9\u4e4b\u9023\u7d50\uff0c\u7d93\u9810\u9078\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u53ef\u5f9e\u8a72\u7b49\u7db2\u7ad9\u4e0b\u8f09\uff1b\u53ca\u6aa2\u67e5\u88dd\u7f6e\uff0c\u7528\u4ee5\u6aa2\u67e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u4e00\u4f4d\u5740\u662f\u5426\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u3002', u'@type': u'claim-text'}
# @num 8
# @id clm8
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c7\u9805\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u9032\u4e00\u6b65\u5305\u542b\u5b58\u53d6\u88dd\u7f6e\uff0c\u7576\u6aa2\u67e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u7528\u4ee5\u5b58\u53d6\u8a72\u64ad\u653e\u8a2d\u5099\u4e4b\u88fd\u9020\u8005\u7684\u7db2\u7ad9\uff0c\n\u4ee5\u4f7f\u8a72\u88fd\u9020\u8005\u7684\u7db2\u7ad9\u641c\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 9
# @id clm9
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c8\u9805\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u5176\u4e2d\u8a72\u5b58\u53d6\u88dd\u7f6e\u5305\u62ec\u767c\u9001\u88dd\u7f6e\uff0c\u7528\u4ee5\u5411\u8a72\u88fd\u9020\u8005\u7684\u7db2\u7ad9\u767c\u9001\u9644\u6709\u95dc\u65bc\u8a72\u64ad\u653e\u8a2d\u5099\u53ca\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u76f8\u95dc\u8cc7\u8a0a\u7684\u8acb\u6c42\u3002', u'@type': u'claim-text'}
# @num 10
# @id clm10
# p {u'#text': u'\u4e00\u7a2e\u7528\u4ee5\u5347\u7d1a\u789f\u7247\u64ad\u653e\u5668\u4e4b\u65b9\u6cd5\uff0c\u5176\u5305\u62ec\uff1a\u78ba\u5b9a\u4e00\u789f\u7247\u4e0a\u4e4b\u4e00\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5167\u5bb9\u985e\u578b\uff0c\u5176\u4e2d\u82e5\u8a72\u64ad\u653e\u5668\u7f3a\u5c11\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4ee5\u64ad\u653e\u8a72\u5167\u5bb9\u7269\u4ef6\u6642\uff0c\u5247\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff1b\u82e5\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff0c\u5247\u78ba\u5b9a\u8a72\u789f\u7247\u662f\u5426\u5305\u542b\u4e00\u9023\u7d50\u81f3\u5305\u542b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7684\u4e00\u7db2\u7ad9\u4e4bURL\u4f4d\u5740\uff1b\u82e5\u8a72\u789f\u7247\u5305\u542b\u8a72\u4f4d\u5740\uff0c\u5247\u4f7f\u7528\u8a72\u4f4d\u5740\u4e0b\u8f09\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u9810\u5148\u5132\u5b58\u4e00\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\uff0c\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u5305\u542b\u81f3\u7db2\u7ad9\u4e4b\u9023\u7d50\uff0c\u7d93\u9810\u9078\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u53ef\u5f9e\u8a72\u7b49\u7db2\u7ad9\u4e0b\u8f09\uff1b\u53ca\u82e5\u8a72\u789f\u7247\u672a\u5305\u542b\u8a72\u4f4d\u5740\uff0c\u5247\u6aa2\u67e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u4e00\u4f4d\u5740\u662f\u5426\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u3002', u'@type': u'claim-text'}
# @num 11
# @id clm11
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c10\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u542b\u82e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u5247\u5b58\u53d6\u8a72\u64ad\u653e\u5668\u4e4b\u88fd\u9020\u8005\u7db2\u7ad9\uff0c\u4ee5\u4f7f\u8a72\u7db2\u7ad9\u6aa2\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4e4b\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 12
# @id clm12
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c11\u9805\u4e4b\u65b9\u6cd5\uff0c\u5176\u4e2d\u8a72\u5b58\u53d6\u6b65\u9a5f\u5305\u62ec\u5411\u8a72\u88fd\u9020\u8005\u7db2\u7ad9\u767c\u9001\u9644\u8207\u8a72\u64ad\u653e\u5668\u53ca\u8a72\u5167\u5bb9\u985e\u578b\u6709\u95dc\u7684\u8cc7\u8a0a\u4e4b\u8acb\u6c42\u7684\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 13
# @id clm13
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c10\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u62ec\uff1a\n\u78ba\u5b9a\u662f\u5426\u80fd\u81ea\u8a72\u7db2\u7ad9\u7372\u5f97\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u82e5\u80fd\u7372\u5f97\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff0c\u5247\u4e0b\u8f09\u8a72\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 14
# @id clm14
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c13\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u62ec\u82e5\u4e0d\u80fd\u81ea\u8a72\u7db2\u7ad9\u7372\u5f97\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff0c\u5247\u901a\u77e5\u4e00\u4f7f\u7528\u8005\u4e4b\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 15
# @id clm15
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c10\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u62ec\u4f7f\u4e00\u4f7f\u7528\u8005\u80fd\u4eba\u5de5\u5730\u81ea\u8a72\u64ad\u653e\u5668\u522a\u9664\u4e00\u4e0b\u8f09\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u7684\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 1
# @id clm1
# p {u'#text': u'\u4e00\u7a2e\u53ef\u64f4\u5c55\u4e4b\u789f\u7247\u64ad\u653e\u5668\uff0c\u5305\u62ec\uff1a\u78ba\u5b9a\u88dd\u7f6e\uff0c\u7528\u4ee5\u78ba\u5b9a\u5728\u4e00\u789f\u7247\u4e0a\u4e4b\u4e00\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5167\u5bb9\u985e\u578b\uff0c\u5176\u4e2d\u82e5\u78ba\u5b9a\u7528\u65bc\u64ad\u653e\u8a72\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4fc2\u7f3a\u5c11\u6642\uff0c\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff1b\u6aa2\u67e5\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\u6642\uff0c\u7528\u4ee5\u6aa2\u67e5\u662f\u5426\u6709\u4e00\u4f4d\u5740\u4fc2\u53ef\u7528\u7684\uff0c\u5176\u4e2d\u8a72\u4f4d\u5740\u4ee3\u8868\u5305\u542b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7684\u4e00\u7db2\u7ad9\u7684\u4e00URL\uff1b\u4e0b\u8f09\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u4f4d\u5740\u4fc2\u53ef\u7528\u6642\uff0c\u7528\u65bc\u4e0b\u8f09\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u9810\u5132\u5b58\u88dd\u7f6e\uff0c\u7528\u4ee5\u9810\u5148\u5132\u5b58\u4e00\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\uff0c\u7d93\u9810\u9078\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u53ef\u5f9e\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e0b\u8f09\uff1b\u53ca\u6aa2\u67e5\u88dd\u7f6e\uff0c\u7528\u4ee5\u6aa2\u67e5\u8207\u8a72\u78ba\u5b9a\u4e4b\u5167\u5bb9\u985e\u578b\u76f8\u95dc\u806f\u4e4b\u4e00\u4f4d\u5740\u662f\u5426\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u3002', u'@type': u'claim-text'}
# @num 2
# @id clm2
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u5b58\u53d6\u88dd\u7f6e\uff0c\u7576\u6aa2\u67e5\u8207\u8a72\u5167\u5bb9\u985e\u578b\u76f8\u95dc\u806f\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u7528\u4ee5\u5b58\u53d6\u4e00\u9810\u8a2d\u7db2\u7ad9\u4ee5\u641c\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 3
# @id clm3
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c2\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u5176\u4e2d\u8a72\u5b58\u53d6\u88dd\u7f6e\u5305\u62ec\u767c\u9001\u88dd\u7f6e\uff0c\u7528\u4ee5\u5411\u8a72\u9810\u8a2d\u7db2\u7ad9\u767c\u9001\u9644\u6709\u95dc\u65bc\u8a72\u64ad\u653e\u5668\u53ca\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u76f8\u95dc\u8cc7\u8a0a\u7684\u8acb\u6c42\u3002', u'@type': u'claim-text'}
# @num 4
# @id clm4
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u78ba\u5b9a\u88dd\u7f6e\uff0c\u7528\u4ee5\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u53ef\u7372\u5f97\uff0c\u53ca\u4e0b\u8f09\u88dd\u7f6e\uff0c\u7576\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u53ef\u7372\u5f97\u6642\uff0c\u7528\u4ee5\u4e0b\u8f09\u8a72\u89e3\u78bc\n\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 5
# @id clm5
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c4\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u901a\u77e5\u88dd\u7f6e\uff0c\u7576\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7121\u6cd5\u7372\u5f97\u6642\uff0c\u7528\u4ee5\u901a\u77e5\u4e00\u4f7f\u7528\u8005\u3002', u'@type': u'claim-text'}
# @num 6
# @id clm6
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u81f4\u80fd\u88dd\u7f6e\uff0c\u4f7f\u4e00\u4f7f\u7528\u8005\u80fd\u5920\u4eba\u5de5\u5730\u522a\u9664\u4e00\u4e0b\u8f09\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 7
# @id clm7
# p {u'#text': u'\u4e00\u7a2e\u53ef\u64f4\u5c55\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u5176\u5305\u542b\uff1a\u78ba\u5b9a\u88dd\u7f6e\uff0c\u7528\u4ee5\u78ba\u5b9a\u5728\u4e00\u8cc7\u6599\u5132\u5b58\u5143\u4ef6\u4e0a\u4e4b\u4e00\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5167\u5bb9\u985e\u578b\uff0c\u5176\u4e2d\u82e5\u8a72\u53ef\u64f4\u5c55\u4e4b\u64ad\u653e\u8a2d\u5099\u7f3a\u5c11\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4ee5\u64a5\u653e\u8a72\u5167\u5bb9\u7269\u4ef6\u6642\uff0c\u5247\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff1b\u78ba\u5b9a\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\u6642\uff0c\u7528\u4ee5\u78ba\u5b9a\u8a72\u8cc7\u6599\u5132\u5b58\u5143\u4ef6\u662f\u5426\u5305\u542b\u4e00\u9023\u7d50\u81f3\u5305\u542b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7684\u4e00\u7db2\u7ad9\u4e4bURL\u4f4d\u5740\uff1b\u4e0b\u8f09\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u8cc7\u6599\u5132\u5b58\u5143\u4ef6\u5305\u542b\u8a72\u4f4d\u5740\u6642\uff0c\u7528\u65bc\u4e0b\u8f09\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u9810\u5132\u5b58\u88dd\u7f6e\uff0c\u7528\u4ee5\u9810\u5148\u5132\u5b58\u4e00\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\uff0c\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u5305\u542b\u81f3\u7db2\u7ad9\u4e4b\u9023\u7d50\uff0c\u7d93\u9810\u9078\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u53ef\u5f9e\u8a72\u7b49\u7db2\u7ad9\u4e0b\u8f09\uff1b\u53ca\u6aa2\u67e5\u88dd\u7f6e\uff0c\u7528\u4ee5\u6aa2\u67e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u4e00\u4f4d\u5740\u662f\u5426\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u3002', u'@type': u'claim-text'}
# @num 8
# @id clm8
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c7\u9805\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u9032\u4e00\u6b65\u5305\u542b\u5b58\u53d6\u88dd\u7f6e\uff0c\u7576\u6aa2\u67e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u7528\u4ee5\u5b58\u53d6\u8a72\u64ad\u653e\u8a2d\u5099\u4e4b\u88fd\u9020\u8005\u7684\u7db2\u7ad9\uff0c\n\u4ee5\u4f7f\u8a72\u88fd\u9020\u8005\u7684\u7db2\u7ad9\u641c\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 9
# @id clm9
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c8\u9805\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u5176\u4e2d\u8a72\u5b58\u53d6\u88dd\u7f6e\u5305\u62ec\u767c\u9001\u88dd\u7f6e\uff0c\u7528\u4ee5\u5411\u8a72\u88fd\u9020\u8005\u7684\u7db2\u7ad9\u767c\u9001\u9644\u6709\u95dc\u65bc\u8a72\u64ad\u653e\u8a2d\u5099\u53ca\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u76f8\u95dc\u8cc7\u8a0a\u7684\u8acb\u6c42\u3002', u'@type': u'claim-text'}
# @num 10
# @id clm10
# p {u'#text': u'\u4e00\u7a2e\u7528\u4ee5\u5347\u7d1a\u789f\u7247\u64ad\u653e\u5668\u4e4b\u65b9\u6cd5\uff0c\u5176\u5305\u62ec\uff1a\u78ba\u5b9a\u4e00\u789f\u7247\u4e0a\u4e4b\u4e00\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5167\u5bb9\u985e\u578b\uff0c\u5176\u4e2d\u82e5\u8a72\u64ad\u653e\u5668\u7f3a\u5c11\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4ee5\u64ad\u653e\u8a72\u5167\u5bb9\u7269\u4ef6\u6642\uff0c\u5247\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff1b\u82e5\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff0c\u5247\u78ba\u5b9a\u8a72\u789f\u7247\u662f\u5426\u5305\u542b\u4e00\u9023\u7d50\u81f3\u5305\u542b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7684\u4e00\u7db2\u7ad9\u4e4bURL\u4f4d\u5740\uff1b\u82e5\u8a72\u789f\u7247\u5305\u542b\u8a72\u4f4d\u5740\uff0c\u5247\u4f7f\u7528\u8a72\u4f4d\u5740\u4e0b\u8f09\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u9810\u5148\u5132\u5b58\u4e00\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\uff0c\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u5305\u542b\u81f3\u7db2\u7ad9\u4e4b\u9023\u7d50\uff0c\u7d93\u9810\u9078\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u53ef\u5f9e\u8a72\u7b49\u7db2\u7ad9\u4e0b\u8f09\uff1b\u53ca\u82e5\u8a72\u789f\u7247\u672a\u5305\u542b\u8a72\u4f4d\u5740\uff0c\u5247\u6aa2\u67e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u4e00\u4f4d\u5740\u662f\u5426\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u3002', u'@type': u'claim-text'}
# @num 11
# @id clm11
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c10\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u542b\u82e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u5247\u5b58\u53d6\u8a72\u64ad\u653e\u5668\u4e4b\u88fd\u9020\u8005\u7db2\u7ad9\uff0c\u4ee5\u4f7f\u8a72\u7db2\u7ad9\u6aa2\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4e4b\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 12
# @id clm12
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c11\u9805\u4e4b\u65b9\u6cd5\uff0c\u5176\u4e2d\u8a72\u5b58\u53d6\u6b65\u9a5f\u5305\u62ec\u5411\u8a72\u88fd\u9020\u8005\u7db2\u7ad9\u767c\u9001\u9644\u8207\u8a72\u64ad\u653e\u5668\u53ca\u8a72\u5167\u5bb9\u985e\u578b\u6709\u95dc\u7684\u8cc7\u8a0a\u4e4b\u8acb\u6c42\u7684\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 13
# @id clm13
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c10\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u62ec\uff1a\n\u78ba\u5b9a\u662f\u5426\u80fd\u81ea\u8a72\u7db2\u7ad9\u7372\u5f97\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u82e5\u80fd\u7372\u5f97\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff0c\u5247\u4e0b\u8f09\u8a72\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 14
# @id clm14
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c13\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u62ec\u82e5\u4e0d\u80fd\u81ea\u8a72\u7db2\u7ad9\u7372\u5f97\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff0c\u5247\u901a\u77e5\u4e00\u4f7f\u7528\u8005\u4e4b\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 15
# @id clm15
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c10\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u62ec\u4f7f\u4e00\u4f7f\u7528\u8005\u80fd\u4eba\u5de5\u5730\u81ea\u8a72\u64ad\u653e\u5668\u522a\u9664\u4e00\u4e0b\u8f09\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u7684\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# ====================================================================================================
# @num 1
# @id clm1
# p {u'#text': u'\u4e00\u7a2e\u53ef\u64f4\u5c55\u4e4b\u789f\u7247\u64ad\u653e\u5668\uff0c\u5305\u62ec\uff1a\u78ba\u5b9a\u88dd\u7f6e\uff0c\u7528\u4ee5\u78ba\u5b9a\u5728\u4e00\u789f\u7247\u4e0a\u4e4b\u4e00\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5167\u5bb9\u985e\u578b\uff0c\u5176\u4e2d\u82e5\u78ba\u5b9a\u7528\u65bc\u64ad\u653e\u8a72\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4fc2\u7f3a\u5c11\u6642\uff0c\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff1b\u6aa2\u67e5\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\u6642\uff0c\u7528\u4ee5\u6aa2\u67e5\u662f\u5426\u6709\u4e00\u4f4d\u5740\u4fc2\u53ef\u7528\u7684\uff0c\u5176\u4e2d\u8a72\u4f4d\u5740\u4ee3\u8868\u5305\u542b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7684\u4e00\u7db2\u7ad9\u7684\u4e00URL\uff1b\u4e0b\u8f09\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u4f4d\u5740\u4fc2\u53ef\u7528\u6642\uff0c\u7528\u65bc\u4e0b\u8f09\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u9810\u5132\u5b58\u88dd\u7f6e\uff0c\u7528\u4ee5\u9810\u5148\u5132\u5b58\u4e00\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\uff0c\u7d93\u9810\u9078\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u53ef\u5f9e\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e0b\u8f09\uff1b\u53ca\u6aa2\u67e5\u88dd\u7f6e\uff0c\u7528\u4ee5\u6aa2\u67e5\u8207\u8a72\u78ba\u5b9a\u4e4b\u5167\u5bb9\u985e\u578b\u76f8\u95dc\u806f\u4e4b\u4e00\u4f4d\u5740\u662f\u5426\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u3002', u'@type': u'claim-text'}
# @num 2
# @id clm2
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u5b58\u53d6\u88dd\u7f6e\uff0c\u7576\u6aa2\u67e5\u8207\u8a72\u5167\u5bb9\u985e\u578b\u76f8\u95dc\u806f\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u7528\u4ee5\u5b58\u53d6\u4e00\u9810\u8a2d\u7db2\u7ad9\u4ee5\u641c\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 3
# @id clm3
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c2\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u5176\u4e2d\u8a72\u5b58\u53d6\u88dd\u7f6e\u5305\u62ec\u767c\u9001\u88dd\u7f6e\uff0c\u7528\u4ee5\u5411\u8a72\u9810\u8a2d\u7db2\u7ad9\u767c\u9001\u9644\u6709\u95dc\u65bc\u8a72\u64ad\u653e\u5668\u53ca\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u76f8\u95dc\u8cc7\u8a0a\u7684\u8acb\u6c42\u3002', u'@type': u'claim-text'}
# @num 4
# @id clm4
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u78ba\u5b9a\u88dd\u7f6e\uff0c\u7528\u4ee5\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u53ef\u7372\u5f97\uff0c\u53ca\u4e0b\u8f09\u88dd\u7f6e\uff0c\u7576\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u53ef\u7372\u5f97\u6642\uff0c\u7528\u4ee5\u4e0b\u8f09\u8a72\u89e3\u78bc\n\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 5
# @id clm5
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c4\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u901a\u77e5\u88dd\u7f6e\uff0c\u7576\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7121\u6cd5\u7372\u5f97\u6642\uff0c\u7528\u4ee5\u901a\u77e5\u4e00\u4f7f\u7528\u8005\u3002', u'@type': u'claim-text'}
# @num 6
# @id clm6
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u81f4\u80fd\u88dd\u7f6e\uff0c\u4f7f\u4e00\u4f7f\u7528\u8005\u80fd\u5920\u4eba\u5de5\u5730\u522a\u9664\u4e00\u4e0b\u8f09\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 7
# @id clm7
# p {u'#text': u'\u4e00\u7a2e\u53ef\u64f4\u5c55\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u5176\u5305\u542b\uff1a\u78ba\u5b9a\u88dd\u7f6e\uff0c\u7528\u4ee5\u78ba\u5b9a\u5728\u4e00\u8cc7\u6599\u5132\u5b58\u5143\u4ef6\u4e0a\u4e4b\u4e00\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5167\u5bb9\u985e\u578b\uff0c\u5176\u4e2d\u82e5\u8a72\u53ef\u64f4\u5c55\u4e4b\u64ad\u653e\u8a2d\u5099\u7f3a\u5c11\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4ee5\u64a5\u653e\u8a72\u5167\u5bb9\u7269\u4ef6\u6642\uff0c\u5247\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff1b\u78ba\u5b9a\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\u6642\uff0c\u7528\u4ee5\u78ba\u5b9a\u8a72\u8cc7\u6599\u5132\u5b58\u5143\u4ef6\u662f\u5426\u5305\u542b\u4e00\u9023\u7d50\u81f3\u5305\u542b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7684\u4e00\u7db2\u7ad9\u4e4bURL\u4f4d\u5740\uff1b\u4e0b\u8f09\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u8cc7\u6599\u5132\u5b58\u5143\u4ef6\u5305\u542b\u8a72\u4f4d\u5740\u6642\uff0c\u7528\u65bc\u4e0b\u8f09\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u9810\u5132\u5b58\u88dd\u7f6e\uff0c\u7528\u4ee5\u9810\u5148\u5132\u5b58\u4e00\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\uff0c\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u5305\u542b\u81f3\u7db2\u7ad9\u4e4b\u9023\u7d50\uff0c\u7d93\u9810\u9078\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u53ef\u5f9e\u8a72\u7b49\u7db2\u7ad9\u4e0b\u8f09\uff1b\u53ca\u6aa2\u67e5\u88dd\u7f6e\uff0c\u7528\u4ee5\u6aa2\u67e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u4e00\u4f4d\u5740\u662f\u5426\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u3002', u'@type': u'claim-text'}
# @num 8
# @id clm8
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c7\u9805\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u9032\u4e00\u6b65\u5305\u542b\u5b58\u53d6\u88dd\u7f6e\uff0c\u7576\u6aa2\u67e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u7528\u4ee5\u5b58\u53d6\u8a72\u64ad\u653e\u8a2d\u5099\u4e4b\u88fd\u9020\u8005\u7684\u7db2\u7ad9\uff0c\n\u4ee5\u4f7f\u8a72\u88fd\u9020\u8005\u7684\u7db2\u7ad9\u641c\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 9
# @id clm9
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c8\u9805\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u5176\u4e2d\u8a72\u5b58\u53d6\u88dd\u7f6e\u5305\u62ec\u767c\u9001\u88dd\u7f6e\uff0c\u7528\u4ee5\u5411\u8a72\u88fd\u9020\u8005\u7684\u7db2\u7ad9\u767c\u9001\u9644\u6709\u95dc\u65bc\u8a72\u64ad\u653e\u8a2d\u5099\u53ca\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u76f8\u95dc\u8cc7\u8a0a\u7684\u8acb\u6c42\u3002', u'@type': u'claim-text'}
# @num 10
# @id clm10
# p {u'#text': u'\u4e00\u7a2e\u7528\u4ee5\u5347\u7d1a\u789f\u7247\u64ad\u653e\u5668\u4e4b\u65b9\u6cd5\uff0c\u5176\u5305\u62ec\uff1a\u78ba\u5b9a\u4e00\u789f\u7247\u4e0a\u4e4b\u4e00\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5167\u5bb9\u985e\u578b\uff0c\u5176\u4e2d\u82e5\u8a72\u64ad\u653e\u5668\u7f3a\u5c11\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4ee5\u64ad\u653e\u8a72\u5167\u5bb9\u7269\u4ef6\u6642\uff0c\u5247\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff1b\u82e5\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff0c\u5247\u78ba\u5b9a\u8a72\u789f\u7247\u662f\u5426\u5305\u542b\u4e00\u9023\u7d50\u81f3\u5305\u542b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7684\u4e00\u7db2\u7ad9\u4e4bURL\u4f4d\u5740\uff1b\u82e5\u8a72\u789f\u7247\u5305\u542b\u8a72\u4f4d\u5740\uff0c\u5247\u4f7f\u7528\u8a72\u4f4d\u5740\u4e0b\u8f09\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u9810\u5148\u5132\u5b58\u4e00\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\uff0c\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u5305\u542b\u81f3\u7db2\u7ad9\u4e4b\u9023\u7d50\uff0c\u7d93\u9810\u9078\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u53ef\u5f9e\u8a72\u7b49\u7db2\u7ad9\u4e0b\u8f09\uff1b\u53ca\u82e5\u8a72\u789f\u7247\u672a\u5305\u542b\u8a72\u4f4d\u5740\uff0c\u5247\u6aa2\u67e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u4e00\u4f4d\u5740\u662f\u5426\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u3002', u'@type': u'claim-text'}
# @num 11
# @id clm11
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c10\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u542b\u82e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u5247\u5b58\u53d6\u8a72\u64ad\u653e\u5668\u4e4b\u88fd\u9020\u8005\u7db2\u7ad9\uff0c\u4ee5\u4f7f\u8a72\u7db2\u7ad9\u6aa2\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4e4b\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 12
# @id clm12
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c11\u9805\u4e4b\u65b9\u6cd5\uff0c\u5176\u4e2d\u8a72\u5b58\u53d6\u6b65\u9a5f\u5305\u62ec\u5411\u8a72\u88fd\u9020\u8005\u7db2\u7ad9\u767c\u9001\u9644\u8207\u8a72\u64ad\u653e\u5668\u53ca\u8a72\u5167\u5bb9\u985e\u578b\u6709\u95dc\u7684\u8cc7\u8a0a\u4e4b\u8acb\u6c42\u7684\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 13
# @id clm13
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c10\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u62ec\uff1a\n\u78ba\u5b9a\u662f\u5426\u80fd\u81ea\u8a72\u7db2\u7ad9\u7372\u5f97\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u82e5\u80fd\u7372\u5f97\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff0c\u5247\u4e0b\u8f09\u8a72\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 14
# @id clm14
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c13\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u62ec\u82e5\u4e0d\u80fd\u81ea\u8a72\u7db2\u7ad9\u7372\u5f97\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff0c\u5247\u901a\u77e5\u4e00\u4f7f\u7528\u8005\u4e4b\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 15
# @id clm15
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c10\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u62ec\u4f7f\u4e00\u4f7f\u7528\u8005\u80fd\u4eba\u5de5\u5730\u81ea\u8a72\u64ad\u653e\u5668\u522a\u9664\u4e00\u4e0b\u8f09\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u7684\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 1
# @id clm1
# p {u'#text': u'\u4e00\u7a2e\u53ef\u64f4\u5c55\u4e4b\u789f\u7247\u64ad\u653e\u5668\uff0c\u5305\u62ec\uff1a\u78ba\u5b9a\u88dd\u7f6e\uff0c\u7528\u4ee5\u78ba\u5b9a\u5728\u4e00\u789f\u7247\u4e0a\u4e4b\u4e00\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5167\u5bb9\u985e\u578b\uff0c\u5176\u4e2d\u82e5\u78ba\u5b9a\u7528\u65bc\u64ad\u653e\u8a72\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4fc2\u7f3a\u5c11\u6642\uff0c\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff1b\u6aa2\u67e5\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\u6642\uff0c\u7528\u4ee5\u6aa2\u67e5\u662f\u5426\u6709\u4e00\u4f4d\u5740\u4fc2\u53ef\u7528\u7684\uff0c\u5176\u4e2d\u8a72\u4f4d\u5740\u4ee3\u8868\u5305\u542b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7684\u4e00\u7db2\u7ad9\u7684\u4e00URL\uff1b\u4e0b\u8f09\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u4f4d\u5740\u4fc2\u53ef\u7528\u6642\uff0c\u7528\u65bc\u4e0b\u8f09\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u9810\u5132\u5b58\u88dd\u7f6e\uff0c\u7528\u4ee5\u9810\u5148\u5132\u5b58\u4e00\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\uff0c\u7d93\u9810\u9078\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u53ef\u5f9e\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e0b\u8f09\uff1b\u53ca\u6aa2\u67e5\u88dd\u7f6e\uff0c\u7528\u4ee5\u6aa2\u67e5\u8207\u8a72\u78ba\u5b9a\u4e4b\u5167\u5bb9\u985e\u578b\u76f8\u95dc\u806f\u4e4b\u4e00\u4f4d\u5740\u662f\u5426\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u3002', u'@type': u'claim-text'}
# @num 2
# @id clm2
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u5b58\u53d6\u88dd\u7f6e\uff0c\u7576\u6aa2\u67e5\u8207\u8a72\u5167\u5bb9\u985e\u578b\u76f8\u95dc\u806f\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u7528\u4ee5\u5b58\u53d6\u4e00\u9810\u8a2d\u7db2\u7ad9\u4ee5\u641c\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 3
# @id clm3
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c2\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u5176\u4e2d\u8a72\u5b58\u53d6\u88dd\u7f6e\u5305\u62ec\u767c\u9001\u88dd\u7f6e\uff0c\u7528\u4ee5\u5411\u8a72\u9810\u8a2d\u7db2\u7ad9\u767c\u9001\u9644\u6709\u95dc\u65bc\u8a72\u64ad\u653e\u5668\u53ca\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u76f8\u95dc\u8cc7\u8a0a\u7684\u8acb\u6c42\u3002', u'@type': u'claim-text'}
# @num 4
# @id clm4
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u78ba\u5b9a\u88dd\u7f6e\uff0c\u7528\u4ee5\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u53ef\u7372\u5f97\uff0c\u53ca\u4e0b\u8f09\u88dd\u7f6e\uff0c\u7576\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u53ef\u7372\u5f97\u6642\uff0c\u7528\u4ee5\u4e0b\u8f09\u8a72\u89e3\u78bc\n\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 5
# @id clm5
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c4\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u901a\u77e5\u88dd\u7f6e\uff0c\u7576\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7121\u6cd5\u7372\u5f97\u6642\uff0c\u7528\u4ee5\u901a\u77e5\u4e00\u4f7f\u7528\u8005\u3002', u'@type': u'claim-text'}
# @num 6
# @id clm6
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u81f4\u80fd\u88dd\u7f6e\uff0c\u4f7f\u4e00\u4f7f\u7528\u8005\u80fd\u5920\u4eba\u5de5\u5730\u522a\u9664\u4e00\u4e0b\u8f09\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 7
# @id clm7
# p {u'#text': u'\u4e00\u7a2e\u53ef\u64f4\u5c55\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u5176\u5305\u542b\uff1a\u78ba\u5b9a\u88dd\u7f6e\uff0c\u7528\u4ee5\u78ba\u5b9a\u5728\u4e00\u8cc7\u6599\u5132\u5b58\u5143\u4ef6\u4e0a\u4e4b\u4e00\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5167\u5bb9\u985e\u578b\uff0c\u5176\u4e2d\u82e5\u8a72\u53ef\u64f4\u5c55\u4e4b\u64ad\u653e\u8a2d\u5099\u7f3a\u5c11\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4ee5\u64a5\u653e\u8a72\u5167\u5bb9\u7269\u4ef6\u6642\uff0c\u5247\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff1b\u78ba\u5b9a\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\u6642\uff0c\u7528\u4ee5\u78ba\u5b9a\u8a72\u8cc7\u6599\u5132\u5b58\u5143\u4ef6\u662f\u5426\u5305\u542b\u4e00\u9023\u7d50\u81f3\u5305\u542b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7684\u4e00\u7db2\u7ad9\u4e4bURL\u4f4d\u5740\uff1b\u4e0b\u8f09\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u8cc7\u6599\u5132\u5b58\u5143\u4ef6\u5305\u542b\u8a72\u4f4d\u5740\u6642\uff0c\u7528\u65bc\u4e0b\u8f09\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u9810\u5132\u5b58\u88dd\u7f6e\uff0c\u7528\u4ee5\u9810\u5148\u5132\u5b58\u4e00\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\uff0c\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u5305\u542b\u81f3\u7db2\u7ad9\u4e4b\u9023\u7d50\uff0c\u7d93\u9810\u9078\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u53ef\u5f9e\u8a72\u7b49\u7db2\u7ad9\u4e0b\u8f09\uff1b\u53ca\u6aa2\u67e5\u88dd\u7f6e\uff0c\u7528\u4ee5\u6aa2\u67e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u4e00\u4f4d\u5740\u662f\u5426\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u3002', u'@type': u'claim-text'}
# @num 8
# @id clm8
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c7\u9805\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u9032\u4e00\u6b65\u5305\u542b\u5b58\u53d6\u88dd\u7f6e\uff0c\u7576\u6aa2\u67e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u7528\u4ee5\u5b58\u53d6\u8a72\u64ad\u653e\u8a2d\u5099\u4e4b\u88fd\u9020\u8005\u7684\u7db2\u7ad9\uff0c\n\u4ee5\u4f7f\u8a72\u88fd\u9020\u8005\u7684\u7db2\u7ad9\u641c\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 9
# @id clm9
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c8\u9805\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u5176\u4e2d\u8a72\u5b58\u53d6\u88dd\u7f6e\u5305\u62ec\u767c\u9001\u88dd\u7f6e\uff0c\u7528\u4ee5\u5411\u8a72\u88fd\u9020\u8005\u7684\u7db2\u7ad9\u767c\u9001\u9644\u6709\u95dc\u65bc\u8a72\u64ad\u653e\u8a2d\u5099\u53ca\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u76f8\u95dc\u8cc7\u8a0a\u7684\u8acb\u6c42\u3002', u'@type': u'claim-text'}
# @num 10
# @id clm10
# p {u'#text': u'\u4e00\u7a2e\u7528\u4ee5\u5347\u7d1a\u789f\u7247\u64ad\u653e\u5668\u4e4b\u65b9\u6cd5\uff0c\u5176\u5305\u62ec\uff1a\u78ba\u5b9a\u4e00\u789f\u7247\u4e0a\u4e4b\u4e00\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5167\u5bb9\u985e\u578b\uff0c\u5176\u4e2d\u82e5\u8a72\u64ad\u653e\u5668\u7f3a\u5c11\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4ee5\u64ad\u653e\u8a72\u5167\u5bb9\u7269\u4ef6\u6642\uff0c\u5247\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff1b\u82e5\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff0c\u5247\u78ba\u5b9a\u8a72\u789f\u7247\u662f\u5426\u5305\u542b\u4e00\u9023\u7d50\u81f3\u5305\u542b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7684\u4e00\u7db2\u7ad9\u4e4bURL\u4f4d\u5740\uff1b\u82e5\u8a72\u789f\u7247\u5305\u542b\u8a72\u4f4d\u5740\uff0c\u5247\u4f7f\u7528\u8a72\u4f4d\u5740\u4e0b\u8f09\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u9810\u5148\u5132\u5b58\u4e00\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\uff0c\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u5305\u542b\u81f3\u7db2\u7ad9\u4e4b\u9023\u7d50\uff0c\u7d93\u9810\u9078\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u53ef\u5f9e\u8a72\u7b49\u7db2\u7ad9\u4e0b\u8f09\uff1b\u53ca\u82e5\u8a72\u789f\u7247\u672a\u5305\u542b\u8a72\u4f4d\u5740\uff0c\u5247\u6aa2\u67e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u4e00\u4f4d\u5740\u662f\u5426\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u3002', u'@type': u'claim-text'}
# @num 11
# @id clm11
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c10\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u542b\u82e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u5247\u5b58\u53d6\u8a72\u64ad\u653e\u5668\u4e4b\u88fd\u9020\u8005\u7db2\u7ad9\uff0c\u4ee5\u4f7f\u8a72\u7db2\u7ad9\u6aa2\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4e4b\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 12
# @id clm12
# ...
# @num 8
# @id clm8
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c7\u9805\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u9032\u4e00\u6b65\u5305\u542b\u5b58\u53d6\u88dd\u7f6e\uff0c\u7576\u6aa2\u67e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u7528\u4ee5\u5b58\u53d6\u8a72\u64ad\u653e\u8a2d\u5099\u4e4b\u88fd\u9020\u8005\u7684\u7db2\u7ad9\uff0c\n\u4ee5\u4f7f\u8a72\u88fd\u9020\u8005\u7684\u7db2\u7ad9\u641c\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 9
# @id clm9
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c8\u9805\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u5176\u4e2d\u8a72\u5b58\u53d6\u88dd\u7f6e\u5305\u62ec\u767c\u9001\u88dd\u7f6e\uff0c\u7528\u4ee5\u5411\u8a72\u88fd\u9020\u8005\u7684\u7db2\u7ad9\u767c\u9001\u9644\u6709\u95dc\u65bc\u8a72\u64ad\u653e\u8a2d\u5099\u53ca\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u76f8\u95dc\u8cc7\u8a0a\u7684\u8acb\u6c42\u3002', u'@type': u'claim-text'}
# @num 10
# @id clm10
# p {u'#text': u'\u4e00\u7a2e\u7528\u4ee5\u5347\u7d1a\u789f\u7247\u64ad\u653e\u5668\u4e4b\u65b9\u6cd5\uff0c\u5176\u5305\u62ec\uff1a\u78ba\u5b9a\u4e00\u789f\u7247\u4e0a\u4e4b\u4e00\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5167\u5bb9\u985e\u578b\uff0c\u5176\u4e2d\u82e5\u8a72\u64ad\u653e\u5668\u7f3a\u5c11\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4ee5\u64ad\u653e\u8a72\u5167\u5bb9\u7269\u4ef6\u6642\uff0c\u5247\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff1b\u82e5\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff0c\u5247\u78ba\u5b9a\u8a72\u789f\u7247\u662f\u5426\u5305\u542b\u4e00\u9023\u7d50\u81f3\u5305\u542b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7684\u4e00\u7db2\u7ad9\u4e4bURL\u4f4d\u5740\uff1b\u82e5\u8a72\u789f\u7247\u5305\u542b\u8a72\u4f4d\u5740\uff0c\u5247\u4f7f\u7528\u8a72\u4f4d\u5740\u4e0b\u8f09\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u9810\u5148\u5132\u5b58\u4e00\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\uff0c\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u5305\u542b\u81f3\u7db2\u7ad9\u4e4b\u9023\u7d50\uff0c\u7d93\u9810\u9078\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u53ef\u5f9e\u8a72\u7b49\u7db2\u7ad9\u4e0b\u8f09\uff1b\u53ca\u82e5\u8a72\u789f\u7247\u672a\u5305\u542b\u8a72\u4f4d\u5740\uff0c\u5247\u6aa2\u67e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u4e00\u4f4d\u5740\u662f\u5426\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u3002', u'@type': u'claim-text'}
# @num 11
# @id clm11
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c10\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u542b\u82e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u5247\u5b58\u53d6\u8a72\u64ad\u653e\u5668\u4e4b\u88fd\u9020\u8005\u7db2\u7ad9\uff0c\u4ee5\u4f7f\u8a72\u7db2\u7ad9\u6aa2\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4e4b\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 12
# @id clm12
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c11\u9805\u4e4b\u65b9\u6cd5\uff0c\u5176\u4e2d\u8a72\u5b58\u53d6\u6b65\u9a5f\u5305\u62ec\u5411\u8a72\u88fd\u9020\u8005\u7db2\u7ad9\u767c\u9001\u9644\u8207\u8a72\u64ad\u653e\u5668\u53ca\u8a72\u5167\u5bb9\u985e\u578b\u6709\u95dc\u7684\u8cc7\u8a0a\u4e4b\u8acb\u6c42\u7684\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 13
# @id clm13
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c10\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u62ec\uff1a\n\u78ba\u5b9a\u662f\u5426\u80fd\u81ea\u8a72\u7db2\u7ad9\u7372\u5f97\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u82e5\u80fd\u7372\u5f97\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff0c\u5247\u4e0b\u8f09\u8a72\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 14
# @id clm14
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c13\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u62ec\u82e5\u4e0d\u80fd\u81ea\u8a72\u7db2\u7ad9\u7372\u5f97\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff0c\u5247\u901a\u77e5\u4e00\u4f7f\u7528\u8005\u4e4b\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 15
# @id clm15
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c10\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u62ec\u4f7f\u4e00\u4f7f\u7528\u8005\u80fd\u4eba\u5de5\u5730\u81ea\u8a72\u64ad\u653e\u5668\u522a\u9664\u4e00\u4e0b\u8f09\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u7684\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 1
# @id clm1
# p {u'#text': u'\u4e00\u7a2e\u53ef\u64f4\u5c55\u4e4b\u789f\u7247\u64ad\u653e\u5668\uff0c\u5305\u62ec\uff1a\u78ba\u5b9a\u88dd\u7f6e\uff0c\u7528\u4ee5\u78ba\u5b9a\u5728\u4e00\u789f\u7247\u4e0a\u4e4b\u4e00\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5167\u5bb9\u985e\u578b\uff0c\u5176\u4e2d\u82e5\u78ba\u5b9a\u7528\u65bc\u64ad\u653e\u8a72\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4fc2\u7f3a\u5c11\u6642\uff0c\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff1b\u6aa2\u67e5\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\u6642\uff0c\u7528\u4ee5\u6aa2\u67e5\u662f\u5426\u6709\u4e00\u4f4d\u5740\u4fc2\u53ef\u7528\u7684\uff0c\u5176\u4e2d\u8a72\u4f4d\u5740\u4ee3\u8868\u5305\u542b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7684\u4e00\u7db2\u7ad9\u7684\u4e00URL\uff1b\u4e0b\u8f09\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u4f4d\u5740\u4fc2\u53ef\u7528\u6642\uff0c\u7528\u65bc\u4e0b\u8f09\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u9810\u5132\u5b58\u88dd\u7f6e\uff0c\u7528\u4ee5\u9810\u5148\u5132\u5b58\u4e00\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\uff0c\u7d93\u9810\u9078\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u53ef\u5f9e\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e0b\u8f09\uff1b\u53ca\u6aa2\u67e5\u88dd\u7f6e\uff0c\u7528\u4ee5\u6aa2\u67e5\u8207\u8a72\u78ba\u5b9a\u4e4b\u5167\u5bb9\u985e\u578b\u76f8\u95dc\u806f\u4e4b\u4e00\u4f4d\u5740\u662f\u5426\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u3002', u'@type': u'claim-text'}
# @num 2
# @id clm2
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u5b58\u53d6\u88dd\u7f6e\uff0c\u7576\u6aa2\u67e5\u8207\u8a72\u5167\u5bb9\u985e\u578b\u76f8\u95dc\u806f\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u7528\u4ee5\u5b58\u53d6\u4e00\u9810\u8a2d\u7db2\u7ad9\u4ee5\u641c\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 3
# @id clm3
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c2\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u5176\u4e2d\u8a72\u5b58\u53d6\u88dd\u7f6e\u5305\u62ec\u767c\u9001\u88dd\u7f6e\uff0c\u7528\u4ee5\u5411\u8a72\u9810\u8a2d\u7db2\u7ad9\u767c\u9001\u9644\u6709\u95dc\u65bc\u8a72\u64ad\u653e\u5668\u53ca\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u76f8\u95dc\u8cc7\u8a0a\u7684\u8acb\u6c42\u3002', u'@type': u'claim-text'}
# @num 4
# @id clm4
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u78ba\u5b9a\u88dd\u7f6e\uff0c\u7528\u4ee5\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u53ef\u7372\u5f97\uff0c\u53ca\u4e0b\u8f09\u88dd\u7f6e\uff0c\u7576\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u53ef\u7372\u5f97\u6642\uff0c\u7528\u4ee5\u4e0b\u8f09\u8a72\u89e3\u78bc\n\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 5
# @id clm5
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c4\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u901a\u77e5\u88dd\u7f6e\uff0c\u7576\u78ba\u5b9a\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7121\u6cd5\u7372\u5f97\u6642\uff0c\u7528\u4ee5\u901a\u77e5\u4e00\u4f7f\u7528\u8005\u3002', u'@type': u'claim-text'}
# @num 6
# @id clm6
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c1\u9805\u4e4b\u64ad\u653e\u5668\uff0c\u9032\u4e00\u6b65\u5305\u542b\u81f4\u80fd\u88dd\u7f6e\uff0c\u4f7f\u4e00\u4f7f\u7528\u8005\u80fd\u5920\u4eba\u5de5\u5730\u522a\u9664\u4e00\u4e0b\u8f09\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 7
# @id clm7
# p {u'#text': u'\u4e00\u7a2e\u53ef\u64f4\u5c55\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u5176\u5305\u542b\uff1a\u78ba\u5b9a\u88dd\u7f6e\uff0c\u7528\u4ee5\u78ba\u5b9a\u5728\u4e00\u8cc7\u6599\u5132\u5b58\u5143\u4ef6\u4e0a\u4e4b\u4e00\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5167\u5bb9\u985e\u578b\uff0c\u5176\u4e2d\u82e5\u8a72\u53ef\u64f4\u5c55\u4e4b\u64ad\u653e\u8a2d\u5099\u7f3a\u5c11\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4ee5\u64a5\u653e\u8a72\u5167\u5bb9\u7269\u4ef6\u6642\uff0c\u5247\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff1b\u78ba\u5b9a\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\u6642\uff0c\u7528\u4ee5\u78ba\u5b9a\u8a72\u8cc7\u6599\u5132\u5b58\u5143\u4ef6\u662f\u5426\u5305\u542b\u4e00\u9023\u7d50\u81f3\u5305\u542b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7684\u4e00\u7db2\u7ad9\u4e4bURL\u4f4d\u5740\uff1b\u4e0b\u8f09\u88dd\u7f6e\uff0c\u5728\u78ba\u5b9a\u8a72\u8cc7\u6599\u5132\u5b58\u5143\u4ef6\u5305\u542b\u8a72\u4f4d\u5740\u6642\uff0c\u7528\u65bc\u4e0b\u8f09\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u9810\u5132\u5b58\u88dd\u7f6e\uff0c\u7528\u4ee5\u9810\u5148\u5132\u5b58\u4e00\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\uff0c\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u5305\u542b\u81f3\u7db2\u7ad9\u4e4b\u9023\u7d50\uff0c\u7d93\u9810\u9078\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u53ef\u5f9e\u8a72\u7b49\u7db2\u7ad9\u4e0b\u8f09\uff1b\u53ca\u6aa2\u67e5\u88dd\u7f6e\uff0c\u7528\u4ee5\u6aa2\u67e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u4e00\u4f4d\u5740\u662f\u5426\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u3002', u'@type': u'claim-text'}
# @num 8
# @id clm8
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c7\u9805\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u9032\u4e00\u6b65\u5305\u542b\u5b58\u53d6\u88dd\u7f6e\uff0c\u7576\u6aa2\u67e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u7528\u4ee5\u5b58\u53d6\u8a72\u64ad\u653e\u8a2d\u5099\u4e4b\u88fd\u9020\u8005\u7684\u7db2\u7ad9\uff0c\n\u4ee5\u4f7f\u8a72\u88fd\u9020\u8005\u7684\u7db2\u7ad9\u641c\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 9
# @id clm9
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c8\u9805\u4e4b\u64ad\u653e\u8a2d\u5099\uff0c\u5176\u4e2d\u8a72\u5b58\u53d6\u88dd\u7f6e\u5305\u62ec\u767c\u9001\u88dd\u7f6e\uff0c\u7528\u4ee5\u5411\u8a72\u88fd\u9020\u8005\u7684\u7db2\u7ad9\u767c\u9001\u9644\u6709\u95dc\u65bc\u8a72\u64ad\u653e\u8a2d\u5099\u53ca\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u76f8\u95dc\u8cc7\u8a0a\u7684\u8acb\u6c42\u3002', u'@type': u'claim-text'}
# @num 10
# @id clm10
# p {u'#text': u'\u4e00\u7a2e\u7528\u4ee5\u5347\u7d1a\u789f\u7247\u64ad\u653e\u5668\u4e4b\u65b9\u6cd5\uff0c\u5176\u5305\u62ec\uff1a\u78ba\u5b9a\u4e00\u789f\u7247\u4e0a\u4e4b\u4e00\u5167\u5bb9\u7269\u4ef6\u4e4b\u4e00\u5167\u5bb9\u985e\u578b\uff0c\u5176\u4e2d\u82e5\u8a72\u64ad\u653e\u5668\u7f3a\u5c11\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4ee5\u64ad\u653e\u8a72\u5167\u5bb9\u7269\u4ef6\u6642\uff0c\u5247\u78ba\u5b9a\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff1b\u82e5\u8a72\u5167\u5bb9\u985e\u578b\u4fc2\u672a\u77e5\uff0c\u5247\u78ba\u5b9a\u8a72\u789f\u7247\u662f\u5426\u5305\u542b\u4e00\u9023\u7d50\u81f3\u5305\u542b\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u7684\u4e00\u7db2\u7ad9\u4e4bURL\u4f4d\u5740\uff1b\u82e5\u8a72\u789f\u7247\u5305\u542b\u8a72\u4f4d\u5740\uff0c\u5247\u4f7f\u7528\u8a72\u4f4d\u5740\u4e0b\u8f09\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u9810\u5148\u5132\u5b58\u4e00\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\uff0c\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u5305\u542b\u81f3\u7db2\u7ad9\u4e4b\u9023\u7d50\uff0c\u7d93\u9810\u9078\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u53ef\u5f9e\u8a72\u7b49\u7db2\u7ad9\u4e0b\u8f09\uff1b\u53ca\u82e5\u8a72\u789f\u7247\u672a\u5305\u542b\u8a72\u4f4d\u5740\uff0c\u5247\u6aa2\u67e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u4e00\u4f4d\u5740\u662f\u5426\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u3002', u'@type': u'claim-text'}
# @num 11
# @id clm11
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c10\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u542b\u82e5\u8a72\u5167\u5bb9\u985e\u578b\u4e4b\u8a72\u4f4d\u5740\u4e0d\u5b58\u5728\u65bc\u8a72\u9810\u8a2d\u4f4d\u5740\u76ee\u9304\u4e2d\u6642\uff0c\u5247\u5b58\u53d6\u8a72\u64ad\u653e\u5668\u4e4b\u88fd\u9020\u8005\u7db2\u7ad9\uff0c\u4ee5\u4f7f\u8a72\u7db2\u7ad9\u6aa2\u7d22\u4e00\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\u4e4b\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 12
# @id clm12
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c11\u9805\u4e4b\u65b9\u6cd5\uff0c\u5176\u4e2d\u8a72\u5b58\u53d6\u6b65\u9a5f\u5305\u62ec\u5411\u8a72\u88fd\u9020\u8005\u7db2\u7ad9\u767c\u9001\u9644\u8207\u8a72\u64ad\u653e\u5668\u53ca\u8a72\u5167\u5bb9\u985e\u578b\u6709\u95dc\u7684\u8cc7\u8a0a\u4e4b\u8acb\u6c42\u7684\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 13
# @id clm13
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c10\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u62ec\uff1a\n\u78ba\u5b9a\u662f\u5426\u80fd\u81ea\u8a72\u7db2\u7ad9\u7372\u5f97\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff1b\u82e5\u80fd\u7372\u5f97\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff0c\u5247\u4e0b\u8f09\u8a72\u89e3\u78bc\u7a0b\u5f0f\u3002', u'@type': u'claim-text'}
# @num 14
# @id clm14
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c13\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u62ec\u82e5\u4e0d\u80fd\u81ea\u8a72\u7db2\u7ad9\u7372\u5f97\u8a72\u5408\u9069\u7684\u89e3\u78bc\u7a0b\u5f0f\uff0c\u5247\u901a\u77e5\u4e00\u4f7f\u7528\u8005\u4e4b\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# @num 15
# @id clm15
# p {u'#text': u'\u5982\u7533\u8acb\u5c08\u5229\u7bc4\u570d\u7b2c10\u9805\u4e4b\u65b9\u6cd5\uff0c\u9032\u4e00\u6b65\u5305\u62ec\u4f7f\u4e00\u4f7f\u7528\u8005\u80fd\u4eba\u5de5\u5730\u81ea\u8a72\u64ad\u653e\u5668\u522a\u9664\u4e00\u4e0b\u8f09\u4e4b\u89e3\u78bc\u7a0b\u5f0f\u7684\u6b65\u9a5f\u3002', u'@type': u'claim-text'}
# ====================================================================================================

# %%
# for i in ary:
#     s = ''
#     for w in i.split('_'):
#         s += '["%s"]'%(w)
#     print s


title = ddd["tw-patent-grant"]["tw-bibliographic-data-grant"]["volno"]


if type(title) == type([]):
    print 'nono'
else:
    print title.strip().encode("utf-8")
#     for i in ddd["tw-patent-grant"]["claims"]["claim"]:
#         if type(i) == type({}):
#             for key in i:
#                 if type(i[key]) == type({}):
#                     for a in i[key]:
#                         print a


# ar = ddd["tw-patent-grant"]["claims"]["claim"]#[0]

# print ar
# print type(ar)
# for i in ar:
#     #for key in i:
#     print i
#     print '='*100
# Out:
# 40

# %%
for i in ary:
    #print len(i)
    s = ''
    #print type(s)
    for w in i.split('_'):
        
        s += '["%s"]'%(w)
    #print type(s)
    print s
    #print str(ddd)+'{}'.format(s)
        #print len(w)
#         for a in range(0,len(i.split('_'))):
#             print ddd[a]
        #print w
        
    print '='*100
# Out:
# ["tw-patent-grant"]["claims"]["claim"]
# ====================================================================================================
# ["tw-patent-grant"]["drawings"]["figure"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["publication-reference"]["document-id"]["date"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["publication-reference"]["document-id"]["kind"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["publication-reference"]["document-id"]["doc-number"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["volno"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["refs"]["ref"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["classification-ipc"]["main-classification"]["#text"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["examiners"]["examiner"]["chinese-name"]["first-name"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["examiners"]["examiner"]["chinese-name"]["last-name"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["parties"]["inventors"]["inventor"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["parties"]["agents"]["agent"]["addressbook"]["address"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["parties"]["agents"]["agent"]["addressbook"]["chinese-name"]["first-name"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["parties"]["agents"]["agent"]["addressbook"]["chinese-name"]["last-name"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["parties"]["applicants"]["applicant"]["addressbook"]["english-name"]["first-name"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["parties"]["applicants"]["applicant"]["addressbook"]["english-name"]["middle-name"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["parties"]["applicants"]["applicant"]["addressbook"]["english-name"]["last-name"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["parties"]["applicants"]["applicant"]["addressbook"]["english-address"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["parties"]["applicants"]["applicant"]["addressbook"]["english-country"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["parties"]["applicants"]["applicant"]["addressbook"]["address"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["parties"]["applicants"]["applicant"]["addressbook"]["chinese-name"]["first-name"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["parties"]["applicants"]["applicant"]["addressbook"]["chinese-name"]["last-name"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["isuno"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["application-publication-reference"]["document-id"]["date"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["application-publication-reference"]["document-id"]["kind"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["application-publication-reference"]["document-id"]["doc-number"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["application-reference"]["document-id"]["date"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["application-reference"]["document-id"]["kind"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["application-reference"]["document-id"]["doc-number"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["invention-title"]["english-title"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["invention-title"]["chinese-title"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["certificate-number"]["document-id"]["date"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["certificate-number"]["document-id"]["kind"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["certificate-number"]["document-id"]["doc-number"]
# ====================================================================================================
# ["tw-patent-grant"]["tw-bibliographic-data-grant"]["kindcode"]
# ====================================================================================================

# %%
from bs4 import BeautifulSoup as bs
with open('E:\\patent_data\\catalog\\cat41\\41006\\094109297.xml') as f:
    soup = bs(f.read())
    #print soup
    print soup.select('tw-patent-grant')[0].select('claims')[0].select('claim')[0].text.strip()
    print soup.select('certificate-number')[0].select('doc-number')[0].text
    print soup.select('classification-ipc')[0].select('main-classification')[0].text
    #certificate-number_doc-number
# Out:
# 一種彩色液晶顯示裝置，其特徵為，組合可進行單色顯示之液晶顯示元件、與可進行彩色顯示之場序驅動液晶顯示元件；前述場序驅動液晶顯示元件係具有可進行單色顯示之液晶顯示元件之1個節段或點區域、或是整合2個以上之節段或點之區域所對應之複數個顯示區域。
# I427581
# G09G3/18

# %%
l = [(1,2),(4,6)]
ll = [(10,5),(9,8)]
print map(lambda (x1,x2),(y1,y2): (x1+y1,x2+y2),l,ll)
# Out:
# [(11, 7), (13, 14)]

# %%
print help(reduce)
# Out:
# Help on built-in function reduce in module __builtin__:
#
# reduce(...)
#     reduce(function, sequence[, initial]) -> value
#
#     Apply a function of two arguments cumulatively to the items of a sequence,
#     from left to right, so as to reduce the sequence to a single value.
#     For example, reduce(lambda x, y: x+y, [1, 2, 3, 4, 5]) calculates
#     ((((1+2)+3)+4)+5).  If initial is present, it is placed before the items
#     of the sequence in the calculation, and serves as a default when the
#     sequence is empty.
#
# None
